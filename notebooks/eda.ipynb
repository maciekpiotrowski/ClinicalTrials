# %%
pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 15.6 MB/s eta 0:00:00 MB/s eta 0:00:0102
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 28.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 29.9 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip3.12 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('../data/raw_studies.csv')
df.head()
# Out:
#    hasResults protocolSection.identificationModule.nctId  \
# 0       False                                NCT04586686
# 1       False                                NCT06315686
# 2        True                                NCT03191786
# 3       False                                NCT00646386
# 4        True                                NCT03228186
#
#   protocolSection.identificationModule.orgStudyIdInfo.id  \
# 0                                     2019COIMBRA001
# 1                                     MA-ENDO-202209
# 2                                            MO29872
# 3                                            M02-518
# 4                                      UMCC 2017.063
#
#   protocolSection.identificationModule.organization.fullName  \
# 0                    Universitair Ziekenhuis Brussel
# 1            Jiangsu Province Nanjing Brain Hospital
# 2                                  Hoffmann-La Roche
# 3                                             Abbott
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Columns: 131 entries, hasResults to resultsSection.moreInfoModule.limitationsAndCaveats.description
# dtypes: bool(3), float64(1), int64(1), object(126)
# memory usage: 50.3+ KB

# %%
df.isnull().sum()
# Out:
# hasResults                                                                           0
# protocolSection.identificationModule.nctId                                           0
# protocolSection.identificationModule.orgStudyIdInfo.id                               0
# protocolSection.identificationModule.organization.fullName                           0
# protocolSection.identificationModule.organization.class                              0
#                                                                                     ..
# annotationSection.annotationModule.unpostedAnnotation.unpostedEvents                49
# derivedSection.miscInfoModule.submissionTracking.estimatedResultsFirstSubmitDate    49
# derivedSection.miscInfoModule.submissionTracking.submissionInfos                    49
# protocolSection.identificationModule.nctIdAliases                                   49
# resultsSection.moreInfoModule.limitationsAndCaveats.description                     48
# ...
